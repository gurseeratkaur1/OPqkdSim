# %%
# from ThOPqkdsim.sim2 import *
# from ThOPqkdsim.sim3 import *
from ThOPqkdsim.sim4 import *
import numpy as np

# %%
# # Create simulator instance
# simulator = BB84Simulator()

# # Run Marcikic experiment simulation
# print("Running simulation with Marcikic experiment parameters...")
# mu_values, key_rates, bers, skr_ub, skr_cascade, skr_ldpc = simulator.simulate_marcikic_experiment()

# # Find the optimal mu and print results
# optimal_idx = np.argmax(skr_ub)
# optimal_mu = mu_values[optimal_idx]

# print(f"Optimal μ: {optimal_mu:.3f}")
# print(f"Key generation rate at optimal μ: {key_rates[optimal_idx]:.6e}")
# print(f"BER at optimal μ: {bers[optimal_idx]:.6f}")
# print(f"Secret key rate (upper bound) at optimal μ: {skr_ub[optimal_idx]:.6e}")
# print(f"Secret key rate (cascade) at optimal μ: {skr_cascade[optimal_idx]:.6e}")
# print(f"Secret key rate (LDPC) at optimal μ: {skr_ldpc[optimal_idx]:.6e}")

# # Convert to bits/s assuming 10 MHz rate
# print(f"\nResults at 10 MHz system rate:")
# print(f"Key generation rate: {key_rates[optimal_idx] * 10e6:.1f} bits/s")
# print(f"Secret key rate (upper bound): {skr_ub[optimal_idx] * 10e6:.1f} bits/s")
# print(f"Secret key rate (cascade): {skr_cascade[optimal_idx] * 10e6:.1f} bits/s")
# print(f"Secret key rate (LDPC): {skr_ldpc[optimal_idx] * 10e6:.1f} bits/s")

# # Plot the results
# plot_results(mu_values, key_rates, bers, skr_ub, skr_cascade, skr_ldpc)

# %%
# Run the simulation
simulator = BB84Simulator()
mu_values, key_rates, bers, skr_ub, skr_cascade, skr_ldpc = simulator.simulate_marcikic_experiment()
plot_results(mu_values, key_rates, bers, skr_ub, skr_cascade, skr_ldpc)
