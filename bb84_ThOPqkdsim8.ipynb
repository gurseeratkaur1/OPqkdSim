# %%
# from ThOPqkdsim.sim2 import *
# from ThOPqkdsim.sim3 import *
from ThOPqkdsim.sim11 import *
import numpy as np

# %%
def run_simulation():
    # Plot QBER vs Mean Photon Number
    mu_range, qber_range = plot_qber_vs_mu()
    
    # Plot SKR vs Mean Photon Number
    mu_range, skr_range = plot_skr_vs_mu()
    
    # Plot QBER vs Distance
    dist_range, qber_dist = plot_qber_vs_distance()
    
    # Plot SKR vs Distance
    dist_range, skr_dist = plot_skr_vs_distance()
    
    # Optional: Plot with eavesdropping
    plot_qber_skr_vs_eavesdropping()

# %%
run_simulation()
